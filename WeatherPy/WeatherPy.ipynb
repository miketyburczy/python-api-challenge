# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?&APPID=" + weather_api_key

City = []
Latitude = []
Longitude = []
MaxTemp = []
Humidity = []
Cloudiness = []
WindSpeed = []
Date = []

print("Beginning Data Retrieval     ")
print("------------------------")

count = 1

for city in cities: 
    
    try:
        response = requests.get(f"{url}&q={city}").json()
        City.append(response["name"])
        Latitude.append(response["coord"]["lat"])
        Longitude.append(response["coord"]["lon"])
        MaxTemp.append(response["main"]["temp_max"])
        Humidity.append(response["main"]["humidity"])
        Cloudiness.append(response["clouds"]["all"])
        WindSpeed.append(response["wind"]["speed"])
        Date.append(response["sys"]["country"])
        city_name = (response["name"])
        
        print(f"Processing Weather Data for Record {count} | {city_name}")
        
        count = count + 1
        
    except:    
        print("Error finding City")
    continue
    
    print("------------------------")
    print("Data Retrieval Complete")
    print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Weather Data for Record 1 | Port Elizabeth
# Processing Weather Data for Record 2 | Adrar
# Processing Weather Data for Record 3 | Fairlie
# Processing Weather Data for Record 4 | Yellowknife
# Processing Weather Data for Record 5 | Arraial do Cabo
# Processing Weather Data for Record 6 | Cherskiy
# Error finding City
# Processing Weather Data for Record 7 | Saskylakh
# Error finding City
# Processing Weather Data for Record 8 | Valparai
# Processing Weather Data for Record 9 | Vaini
# Processing Weather Data for Record 10 | Sudak
# Processing Weather Data for Record 11 | Boende
# Processing Weather Data for Record 12 | Faanui
# Processing Weather Data for Record 13 | Ushuaia
# Processing Weather Data for Record 14 | Zhangaözen
# Processing Weather Data for Record 15 | Ryōtsu-minato
# Processing Weather Data for Record 16 | Souillac
# Processing Weather Data for Record 17 | Bandarbeyla
# Processing Weather Data for Record 18 | San Patricio
# Processing Weather Data for Record 19 | Leningradskiy
# Processing Weather Data for Record 20 | Chissamba
# Processing Weather Data for Record 21 | Narón
# Processing Weather Data for Record 22 | Tingo María
# Processing Weather Data for Record 23 | Padang
# Processing Weather Data for Record 24 | Mahébourg
# Processing Weather Data for Record 25 | Kaitangata
# Processing Weather Data for Record 26 | Saint-Philippe
# Processing Weather Data for Record 27 | Rikitea
# Processing Weather Data for Record 28 | Sekoma
# Processing Weather Data for Record 29 | Atuona
# Processing Weather Data for Record 30 | Nchelenge
# Processing Weather Data for Record 31 | Mount Gambier
# Processing Weather Data for Record 32 | Nome
# Processing Weather Data for Record 33 | Haderslev
# Processing Weather Data for Record 34 | Norman Wells
# Error finding City
# Processing Weather Data for Record 35 | Bluff
# Processing Weather Data for Record 36 | Airai
# Processing Weather Data for Record 37 | Koróni
# Processing Weather Data for Record 38 | Gornopravdinsk
# Processing Weather Data for Record 39 | Puerto Ayora
# Processing Weather Data for Record 40 | Meulaboh
# Processing Weather Data for Record 41 | North Bend
# Processing Weather Data for Record 42 | Hilo
# Processing Weather Data for Record 43 | New Ulm
# Processing Weather Data for Record 44 | Bredasdorp
# Processing Weather Data for Record 45 | Chui
# Error finding City
# Processing Weather Data for Record 46 | San Miguel de Cauri
# Processing Weather Data for Record 47 | Jamestown
# Processing Weather Data for Record 48 | Busselton
# Processing Weather Data for Record 49 | Mount Isa
# Processing Weather Data for Record 50 | Guerrero Negro
# Processing Weather Data for Record 51 | Upernavik
# Processing Weather Data for Record 52 | Malé
# Processing Weather Data for Record 53 | Qaanaaq
# Processing Weather Data for Record 54 | Hermanus
# Processing Weather Data for Record 55 | Tabuny
# Processing Weather Data for Record 56 | Bambous Virieux
# Processing Weather Data for Record 57 | Ancud
# Processing Weather Data for Record 58 | Tiznit Province
# Processing Weather Data for Record 59 | Flin Flon
# Processing Weather Data for Record 60 | Torbay
# Processing Weather Data for Record 61 | Richards Bay
# Processing Weather Data for Record 62 | Sumbawanga
# Processing Weather Data for Record 63 | Boguchany
# Processing Weather Data for Record 64 | East London
# Processing Weather Data for Record 65 | Egvekinot
# Processing Weather Data for Record 66 | Batticaloa
# Processing Weather Data for Record 67 | Albany
# Processing Weather Data for Record 68 | Mataura
# Processing Weather Data for Record 69 | East Northport
# Processing Weather Data for Record 70 | New Norfolk
# Error finding City
# Processing Weather Data for Record 71 | Timmins
# Processing Weather Data for Record 72 | Butaritari
# Processing Weather Data for Record 73 | Bethel
# Processing Weather Data for Record 74 | Yatou
# Processing Weather Data for Record 75 | Castro
# Processing Weather Data for Record 76 | Punta Arenas
# Processing Weather Data for Record 77 | Dikson
# Processing Weather Data for Record 78 | Fortuna
# Processing Weather Data for Record 79 | Mölln
# Processing Weather Data for Record 80 | Longyearbyen
# Processing Weather Data for Record 81 | Chicama
# Processing Weather Data for Record 82 | Ratnagiri
# Processing Weather Data for Record 83 | Praia da Vitória
# Processing Weather Data for Record 84 | Tazovsky
# Error finding City
# Processing Weather Data for Record 85 | Shenjiamen
# Processing Weather Data for Record 86 | Port Hardy
# Processing Weather Data for Record 87 | Saint Paul Harbor
# Processing Weather Data for Record 88 | Cape Town
# Processing Weather Data for Record 89 | Avarua
# Processing Weather Data for Record 90 | Hobart
# Processing Weather Data for Record 91 | Kapaa
# Processing Weather Data for Record 92 | Coari
# Processing Weather Data for Record 93 | Necochea
# Processing Weather Data for Record 94 | Hong Kong
# Error finding City
# Processing Weather Data for Record 95 | Bohicon
# Error finding City
# Processing Weather Data for Record 96 | Pozo Colorado
# Processing Weather Data for Record 97 | Arrondissement de Toul
# Processing Weather Data for Record 98 | San Jerónimo
# Processing Weather Data for Record 99 | Thompson
# Processing Weather Data for Record 100 | Novoagansk
# Error finding City
# Processing Weather Data for Record 101 | Tutóia
# Error finding City
# Processing Weather Data for Record 102 | Takoradze
# Processing Weather Data for Record 103 | Fairbanks
# Processing Weather Data for Record 104 | Tuktoyaktuk
# Processing Weather Data for Record 105 | Pevek
# Processing Weather Data for Record 106 | Carnarvon
# Error finding City
# Error finding City
# Processing Weather Data for Record 107 | Sakakah
# Processing Weather Data for Record 108 | Manutuke
# Processing Weather Data for Record 109 | Boma
# Processing Weather Data for Record 110 | Cockburn Town
# Processing Weather Data for Record 111 | George Town
# Processing Weather Data for Record 112 | Hambantota
# Processing Weather Data for Record 113 | Winnemucca
# Processing Weather Data for Record 114 | Paita
# Processing Weather Data for Record 115 | Waingapu
# Processing Weather Data for Record 116 | Jämsä
# Error finding City
# Processing Weather Data for Record 117 | Östersund
# Processing Weather Data for Record 118 | Aykhal
# Processing Weather Data for Record 119 | Ascension
# Error finding City
# Processing Weather Data for Record 120 | Saint-Joseph
# Processing Weather Data for Record 121 | Omboué
# Processing Weather Data for Record 122 | Hualmay
# Processing Weather Data for Record 123 | Dalbandin
# Processing Weather Data for Record 124 | Clyde River
# Processing Weather Data for Record 125 | Itarema
# Processing Weather Data for Record 126 | Rio Grande
# Processing Weather Data for Record 127 | Al Bardīyah
# Processing Weather Data for Record 128 | Hithadhoo
# Processing Weather Data for Record 129 | Touros
# Processing Weather Data for Record 130 | Tura
# Processing Weather Data for Record 131 | Maracaçumé
# Processing Weather Data for Record 132 | Chistogorskiy
# Error finding City
# Processing Weather Data for Record 133 | Dunedin
# Processing Weather Data for Record 134 | Cap Malheureux
# Processing Weather Data for Record 135 | Batagay
# Processing Weather Data for Record 136 | Barrow
# Processing Weather Data for Record 137 | Pospelikha
# Processing Weather Data for Record 138 | Codrington
# Processing Weather Data for Record 139 | Iqaluit
# Processing Weather Data for Record 140 | Lüderitz
# Processing Weather Data for Record 141 | Dvinskoy
# Processing Weather Data for Record 142 | Raja
# Processing Weather Data for Record 143 | Port Hedland
# Processing Weather Data for Record 144 | Yārāda
# Processing Weather Data for Record 145 | Cabo San Lucas
# Processing Weather Data for Record 146 | Lebu
# Processing Weather Data for Record 147 | Lærdal
# Processing Weather Data for Record 148 | Presidencia Roque Sáenz Peña
# Processing Weather Data for Record 149 | Coyhaique
# Processing Weather Data for Record 150 | ‘Āhuimanu
# Processing Weather Data for Record 151 | Westport
# Processing Weather Data for Record 152 | Sun Valley
# Processing Weather Data for Record 153 | Grand Gaube
# Error finding City
# Processing Weather Data for Record 154 | Dubai
# Processing Weather Data for Record 155 | Prescott
# Processing Weather Data for Record 156 | Warrington
# Error finding City
# Error finding City
# Processing Weather Data for Record 157 | Bourail
# Processing Weather Data for Record 158 | Salalah
# Processing Weather Data for Record 159 | Saldanha
# Processing Weather Data for Record 160 | Miyako
# Processing Weather Data for Record 161 | Badnāwar
# Error finding City
# Processing Weather Data for Record 162 | Vilyuysk
# Error finding City
# Processing Weather Data for Record 163 | Havelock
# Processing Weather Data for Record 164 | Constitución
# Processing Weather Data for Record 165 | Khatanga
# Processing Weather Data for Record 166 | Auki
# Processing Weather Data for Record 167 | Ponta do Sol
# Processing Weather Data for Record 168 | Dzaoudzi
# Processing Weather Data for Record 169 | Makat
# Processing Weather Data for Record 170 | Tasiilaq
# Processing Weather Data for Record 171 | Kahului
# Processing Weather Data for Record 172 | Rocha
# Processing Weather Data for Record 173 | Huarmey
# Processing Weather Data for Record 174 | Hofn
# Processing Weather Data for Record 175 | Nago
# Processing Weather Data for Record 176 | Takāb
# Error finding City
# Processing Weather Data for Record 177 | Pisco
# Processing Weather Data for Record 178 | Bassar
# Processing Weather Data for Record 179 | Moerai
# Processing Weather Data for Record 180 | Katangli
# Processing Weather Data for Record 181 | Ust'-Koksa
# Processing Weather Data for Record 182 | Iskateley
# Processing Weather Data for Record 183 | Vardø
# Processing Weather Data for Record 184 | Aquiraz
# Processing Weather Data for Record 185 | Saint-Jean-de-Braye
# Processing Weather Data for Record 186 | Saint George
# Processing Weather Data for Record 187 | Riyadh
# Processing Weather Data for Record 188 | Caucayá
# Processing Weather Data for Record 189 | Kārkala
# Error finding City
# Processing Weather Data for Record 190 | Vao
# Error finding City
# Processing Weather Data for Record 191 | Aklavik
# Processing Weather Data for Record 192 | Esperance
# Error finding City
# Error finding City
# Processing Weather Data for Record 193 | Provideniya
# Processing Weather Data for Record 194 | Qingdao
# Processing Weather Data for Record 195 | Turan
# Processing Weather Data for Record 196 | Haines Junction
# Processing Weather Data for Record 197 | Dryden
# Processing Weather Data for Record 198 | Itoman
# Processing Weather Data for Record 199 | Coquimbo
# Processing Weather Data for Record 200 | Marsh Harbour
# Processing Weather Data for Record 201 | Finnsnes
# Processing Weather Data for Record 202 | Shestakovo
# Processing Weather Data for Record 203 | Sterling
# Processing Weather Data for Record 204 | Ribeira Grande
# Processing Weather Data for Record 205 | Katsuura
# Processing Weather Data for Record 206 | Maniitsoq
# Processing Weather Data for Record 207 | Gamba
# Processing Weather Data for Record 208 | Vicksburg
# Processing Weather Data for Record 209 | Chokurdakh
# Processing Weather Data for Record 210 | Assiut
# Processing Weather Data for Record 211 | Mahibadhoo
# Processing Weather Data for Record 212 | Prince Rupert
# Processing Weather Data for Record 213 | Øksfjord
# Processing Weather Data for Record 214 | São Filipe
# Processing Weather Data for Record 215 | Ngaoundéré
# Error finding City
# Processing Weather Data for Record 216 | Camapuã
# Processing Weather Data for Record 217 | Port Alfred
# Processing Weather Data for Record 218 | Sémbé
# Processing Weather Data for Record 219 | Yako
# Processing Weather Data for Record 220 | Jacareacanga
# Processing Weather Data for Record 221 | Santa Isabel Rio Negro
# Processing Weather Data for Record 222 | Nara
# Processing Weather Data for Record 223 | Chara
# Processing Weather Data for Record 224 | Deputatsky
# Error finding City
# Processing Weather Data for Record 225 | Valparaíso
# Error finding City
# Error finding City
# Processing Weather Data for Record 226 | Half Moon Bay
# Processing Weather Data for Record 227 | Nuuk
# Processing Weather Data for Record 228 | Mbour
# Processing Weather Data for Record 229 | Kutum
# Processing Weather Data for Record 230 | Conde
# Processing Weather Data for Record 231 | Sinnamary
# Processing Weather Data for Record 232 | Luanda
# Processing Weather Data for Record 233 | Inyonga
# Error finding City
# Processing Weather Data for Record 234 | Port Blair
# Error finding City
# Processing Weather Data for Record 235 | Hasaki
# Processing Weather Data for Record 236 | Nikolskoye
# Processing Weather Data for Record 237 | Zeya
# Processing Weather Data for Record 238 | Talnakh
# Processing Weather Data for Record 239 | Virginia Beach
# Processing Weather Data for Record 240 | Callaway
# Processing Weather Data for Record 241 | Lorengau
# Processing Weather Data for Record 242 | Sisimiut
# Processing Weather Data for Record 243 | Ostrovnoy
# Processing Weather Data for Record 244 | Severo-Kuril'sk
# Processing Weather Data for Record 245 | Qaqortoq
# Processing Weather Data for Record 246 | Kiryat Gat
# Error finding City
# Processing Weather Data for Record 247 | Sakaraha
# Processing Weather Data for Record 248 | Kattivākkam
# Processing Weather Data for Record 249 | Yangi Marg`ilon
# Processing Weather Data for Record 250 | Scarborough
# Processing Weather Data for Record 251 | Bara
# Processing Weather Data for Record 252 | Yuancheng
# Processing Weather Data for Record 253 | Yulara
# Processing Weather Data for Record 254 | Minna
# Processing Weather Data for Record 255 | Ekhabi
# Processing Weather Data for Record 256 | Klyuchi
# Processing Weather Data for Record 257 | Grindavik
# Processing Weather Data for Record 258 | Te Anau
# Error finding City
# Processing Weather Data for Record 259 | Tsimmerbude
# Processing Weather Data for Record 260 | Kindu
# Processing Weather Data for Record 261 | Geraldton
# Processing Weather Data for Record 262 | Bonavista
# Processing Weather Data for Record 263 | São Fidélis
# Processing Weather Data for Record 264 | Sumenep
# Processing Weather Data for Record 265 | Peru
# Processing Weather Data for Record 266 | Kavieng
# Processing Weather Data for Record 267 | Mirny
# Processing Weather Data for Record 268 | Porbandar
# Processing Weather Data for Record 269 | Palora
# Processing Weather Data for Record 270 | Henties Bay
# Processing Weather Data for Record 271 | Deniliquin
# Processing Weather Data for Record 272 | Naze
# Error finding City
# Error finding City
# Processing Weather Data for Record 273 | Liverpool
# Processing Weather Data for Record 274 | Goderich
# Processing Weather Data for Record 275 | Alamada
# Processing Weather Data for Record 276 | Vila Franca do Campo
# Processing Weather Data for Record 277 | Preobrazheniye
# Processing Weather Data for Record 278 | Little Baguio
# Error finding City
# Processing Weather Data for Record 279 | Isangel
# Processing Weather Data for Record 280 | Kabalo
# Processing Weather Data for Record 281 | Florø
# Processing Weather Data for Record 282 | Qui Nhon
# Processing Weather Data for Record 283 | Aurangabad
# Processing Weather Data for Record 284 | Ponta Delgada
# Processing Weather Data for Record 285 | Ténenkou
# Processing Weather Data for Record 286 | Dudinka
# Processing Weather Data for Record 287 | São João da Barra
# Processing Weather Data for Record 288 | Ngunguru
# Processing Weather Data for Record 289 | Tiksi
# Processing Weather Data for Record 290 | Port Shepstone
# Processing Weather Data for Record 291 | Yichun
# Processing Weather Data for Record 292 | Verkhnetulomskiy
# Processing Weather Data for Record 293 | Laguna de Perlas
# Processing Weather Data for Record 294 | Tromsø
# Processing Weather Data for Record 295 | Nelson Bay
# Processing Weather Data for Record 296 | Pueblo
# Processing Weather Data for Record 297 | Sar-e Pul
# Processing Weather Data for Record 298 | Karasburg
# Processing Weather Data for Record 299 | Black River
# Processing Weather Data for Record 300 | Bagotville
# Processing Weather Data for Record 301 | Khovd
# Processing Weather Data for Record 302 | Santa Cruz de la Sierra
# Processing Weather Data for Record 303 | Johnson City
# Processing Weather Data for Record 304 | Sena Madureira
# Processing Weather Data for Record 305 | Bunia
# Processing Weather Data for Record 306 | Portland
# Error finding City
# Processing Weather Data for Record 307 | Semporna
# Processing Weather Data for Record 308 | Broome
# Processing Weather Data for Record 309 | Mareeba
# Processing Weather Data for Record 310 | Biak
# Processing Weather Data for Record 311 | Hobyo
# Processing Weather Data for Record 312 | Bīghāpur Khurd
# Processing Weather Data for Record 313 | Erenhot
# Processing Weather Data for Record 314 | Merauke
# Processing Weather Data for Record 315 | Måløy
# Processing Weather Data for Record 316 | Mocuba
# Error finding City
# Processing Weather Data for Record 317 | Jacksonville
# Processing Weather Data for Record 318 | Cidreira
# Processing Weather Data for Record 319 | Terrace Bay
# Processing Weather Data for Record 320 | Capácuaro
# Processing Weather Data for Record 321 | Zvishavane
# Error finding City
# Processing Weather Data for Record 322 | Talavera de la Reina
# Processing Weather Data for Record 323 | Sikandarpur
# Processing Weather Data for Record 324 | Drumnadrochit
# Processing Weather Data for Record 325 | Raymondville
# Processing Weather Data for Record 326 | Fomboni
# Processing Weather Data for Record 327 | Shingū
# Processing Weather Data for Record 328 | São José da Coroa Grande
# Processing Weather Data for Record 329 | Boa Vista
# Processing Weather Data for Record 330 | Innisfail
# Processing Weather Data for Record 331 | Novorozhdestvenskaya
# Processing Weather Data for Record 332 | Srednekolymsk
# Processing Weather Data for Record 333 | Cabadiangan
# Error finding City
# Processing Weather Data for Record 334 | Evensk
# Processing Weather Data for Record 335 | Pacific Grove
# Processing Weather Data for Record 336 | Caravelas
# Processing Weather Data for Record 337 | Oxford
# Processing Weather Data for Record 338 | Tegul'det
# Processing Weather Data for Record 339 | Coahuayana Viejo
# Processing Weather Data for Record 340 | Batié
# Processing Weather Data for Record 341 | Olinda
# Processing Weather Data for Record 342 | Antalaha
# Processing Weather Data for Record 343 | Jiwani
# Processing Weather Data for Record 344 | Betsiamites
# Processing Weather Data for Record 345 | Laas
# Processing Weather Data for Record 346 | Scalea
# Processing Weather Data for Record 347 | Gondal
# Processing Weather Data for Record 348 | Ust-Maya
# Error finding City
# Error finding City
# Processing Weather Data for Record 349 | Chipinge
# Processing Weather Data for Record 350 | Lichinga
# Processing Weather Data for Record 351 | Yabrūd
# Processing Weather Data for Record 352 | Verkhnevilyuysk
# Processing Weather Data for Record 353 | Beringovskiy
# Processing Weather Data for Record 354 | Bajil
# Processing Weather Data for Record 355 | Lavrentiya
# Processing Weather Data for Record 356 | Vershino-Shakhtaminskiy
# Processing Weather Data for Record 357 | Sri Aman
# Processing Weather Data for Record 358 | Summerville
# Processing Weather Data for Record 359 | Roswell
# Processing Weather Data for Record 360 | Forsytheganj
# Processing Weather Data for Record 361 | Ossora
# Processing Weather Data for Record 362 | Bhawānipatna
# Processing Weather Data for Record 363 | Laguna
# Processing Weather Data for Record 364 | Lumeje
# Processing Weather Data for Record 365 | Mar del Plata
# Processing Weather Data for Record 366 | Qasigiannguit
# Processing Weather Data for Record 367 | Sitka
# Processing Weather Data for Record 368 | Kumul
# Processing Weather Data for Record 369 | Chengde
# Processing Weather Data for Record 370 | Yerofey Pavlovich
# Processing Weather Data for Record 371 | Malibu
# Processing Weather Data for Record 372 | Tuy Hoa
# Error finding City
# Processing Weather Data for Record 373 | Bubaque
# Processing Weather Data for Record 374 | Shahrud
# Processing Weather Data for Record 375 | Maţāy
# Processing Weather Data for Record 376 | Marechal Cândido Rondon
# Processing Weather Data for Record 377 | Waipawa
# Processing Weather Data for Record 378 | Tete
# Processing Weather Data for Record 379 | Banjar
# Processing Weather Data for Record 380 | Tomatlán
# Processing Weather Data for Record 381 | Namatanai
# Processing Weather Data for Record 382 | Klaksvík
# Processing Weather Data for Record 383 | Nowa Sól
# Processing Weather Data for Record 384 | Sioux Lookout
# Processing Weather Data for Record 385 | Severo-Yeniseyskiy
# Processing Weather Data for Record 386 | Lompoc
# Processing Weather Data for Record 387 | Mezhdurechensk
# Processing Weather Data for Record 388 | Flinders
# Processing Weather Data for Record 389 | Kalabagh
# Processing Weather Data for Record 390 | Qinzhou
# Processing Weather Data for Record 391 | Nānākuli
# Processing Weather Data for Record 392 | Asău
# Processing Weather Data for Record 393 | Nakambala
# Processing Weather Data for Record 394 | Tateyama
# Processing Weather Data for Record 395 | Beisfjord
# Processing Weather Data for Record 396 | Xam Nua
# Processing Weather Data for Record 397 | Vestmannaeyjar
# Processing Weather Data for Record 398 | Prado
# Processing Weather Data for Record 399 | Nador
# Processing Weather Data for Record 400 | Bad Sooden-Allendorf
# Processing Weather Data for Record 401 | Mossendjo
# Processing Weather Data for Record 402 | Malakal
# Processing Weather Data for Record 403 | Ust-Nera
# Processing Weather Data for Record 404 | Ilulissat
# Processing Weather Data for Record 405 | Torrington
# Processing Weather Data for Record 406 | Charters Towers
# Processing Weather Data for Record 407 | Syracuse
# Processing Weather Data for Record 408 | Termez
# Processing Weather Data for Record 409 | Peace River
# Processing Weather Data for Record 410 | Deqing
# Processing Weather Data for Record 411 | Srandakan
# Processing Weather Data for Record 412 | Gal'bshtadt
# Processing Weather Data for Record 413 | Kavaratti
# Processing Weather Data for Record 414 | Sobolevo
# Processing Weather Data for Record 415 | Saint-François
# Processing Weather Data for Record 416 | Kota Kinabalu
# Processing Weather Data for Record 417 | Mossamedes
# Processing Weather Data for Record 418 | Aljezur
# Processing Weather Data for Record 419 | Elizabeth City
# Processing Weather Data for Record 420 | Ballina
# Processing Weather Data for Record 421 | Tulagi
# Processing Weather Data for Record 422 | Nabire
# Processing Weather Data for Record 423 | Samarai
# Processing Weather Data for Record 424 | Ulladulla
# Processing Weather Data for Record 425 | Ambon City
# Processing Weather Data for Record 426 | Manche
# Processing Weather Data for Record 427 | Gumdag
# Processing Weather Data for Record 428 | Dingle
# Processing Weather Data for Record 429 | Dongsheng
# Processing Weather Data for Record 430 | Amapá
# Processing Weather Data for Record 431 | Beruwala
# Processing Weather Data for Record 432 | Yar-Sale
# Processing Weather Data for Record 433 | Örnsköldsvik
# Processing Weather Data for Record 434 | Mwinilunga
# Processing Weather Data for Record 435 | Dolores
# Processing Weather Data for Record 436 | Comodoro Rivadavia
# Processing Weather Data for Record 437 | Emerald
# Processing Weather Data for Record 438 | Aneby
# Processing Weather Data for Record 439 | Arman'
# Processing Weather Data for Record 440 | Kathu
# Processing Weather Data for Record 441 | Agüimes
# Processing Weather Data for Record 442 | Nemuro
# Error finding City
# Processing Weather Data for Record 443 | Junín
# Processing Weather Data for Record 444 | Dauphin
# Processing Weather Data for Record 445 | Rawson
# Processing Weather Data for Record 446 | Banes
# Processing Weather Data for Record 447 | Noumea
# Processing Weather Data for Record 448 | Kamaishi
# Processing Weather Data for Record 449 | Burns Lake
# Processing Weather Data for Record 450 | Elko
# Processing Weather Data for Record 451 | Manacapuru
# Processing Weather Data for Record 452 | Beloha
# Processing Weather Data for Record 453 | Myitkyina
# Processing Weather Data for Record 454 | Iralaya
# Processing Weather Data for Record 455 | Avon Park
# Processing Weather Data for Record 456 | Labuhan
# Processing Weather Data for Record 457 | Kurumkan
# Processing Weather Data for Record 458 | Vila Velha
# Processing Weather Data for Record 459 | Bilma
# Processing Weather Data for Record 460 | Belle Fourche
# Processing Weather Data for Record 461 | Alexandria
# Processing Weather Data for Record 462 | Maebaru-chūō
# Error finding City
# Processing Weather Data for Record 463 | Aksay
# Processing Weather Data for Record 464 | Bam
# Error finding City
# Processing Weather Data for Record 465 | São Félix do Xingu
# Processing Weather Data for Record 466 | Omsukchan
# Processing Weather Data for Record 467 | Avera
# Processing Weather Data for Record 468 | Acapulco de Juárez
# Processing Weather Data for Record 469 | Broken Hill
# Processing Weather Data for Record 470 | Kirovo-Chepetsk
# Processing Weather Data for Record 471 | Menongue
# Processing Weather Data for Record 472 | Phu Ly
# Processing Weather Data for Record 473 | Nantucket
# Processing Weather Data for Record 474 | Lincoln
# Processing Weather Data for Record 475 | Bengkulu
# Processing Weather Data for Record 476 | Palmer
# Processing Weather Data for Record 477 | Bud
# Processing Weather Data for Record 478 | Lata
# Processing Weather Data for Record 479 | Safaga
# Processing Weather Data for Record 480 | Sur
# Processing Weather Data for Record 481 | Ahipara
# Processing Weather Data for Record 482 | Bryan
# Processing Weather Data for Record 483 | Manaus
# Error finding City
# Processing Weather Data for Record 484 | Asilah
# Processing Weather Data for Record 485 | Calabozo
# Error finding City
# Processing Weather Data for Record 486 | Les Trois-Îlets
# Processing Weather Data for Record 487 | Rockport
# Error finding City
# Processing Weather Data for Record 488 | Gaza
# Processing Weather Data for Record 489 | Pangai
# Processing Weather Data for Record 490 | Honiara
# Processing Weather Data for Record 491 | Lerwick
# Processing Weather Data for Record 492 | Kirgiz-Miyaki
# Processing Weather Data for Record 493 | Lagoa
# Processing Weather Data for Record 494 | Clovis
# Processing Weather Data for Record 495 | Yanam
# Processing Weather Data for Record 496 | Champerico
# Processing Weather Data for Record 497 | Hūn
# Processing Weather Data for Record 498 | Matipó
# Processing Weather Data for Record 499 | Vestmanna
# Processing Weather Data for Record 500 | Estelle
# Processing Weather Data for Record 501 | Old Shinyanga
# Processing Weather Data for Record 502 | Iwaki
# Processing Weather Data for Record 503 | Riberalta
# Processing Weather Data for Record 504 | Koumra
# Processing Weather Data for Record 505 | Jinxi
# Processing Weather Data for Record 506 | Mahon
# Processing Weather Data for Record 507 | Itapuranga
# Processing Weather Data for Record 508 | Saravan
# Processing Weather Data for Record 509 | Staryy Nadym
# Processing Weather Data for Record 510 | Shache
# Processing Weather Data for Record 511 | Paka
# Processing Weather Data for Record 512 | Karratha
# Error finding City
# Processing Weather Data for Record 513 | Belmonte
# Processing Weather Data for Record 514 | Margherita
# Processing Weather Data for Record 515 | Raudeberg
# Error finding City
# Processing Weather Data for Record 516 | Miyang
# Processing Weather Data for Record 517 | Lima
# Processing Weather Data for Record 518 | Kosh-Agach
# Processing Weather Data for Record 519 | Nanortalik
# Processing Weather Data for Record 520 | Gemena
# Processing Weather Data for Record 521 | Cacoal
# Processing Weather Data for Record 522 | Katobu
# Processing Weather Data for Record 523 | Tūkrah
# Processing Weather Data for Record 524 | Alvorada
# Processing Weather Data for Record 525 | Kununurra
# Processing Weather Data for Record 526 | Poum
# Processing Weather Data for Record 527 | Natal
# Processing Weather Data for Record 528 | Kaliua
# Processing Weather Data for Record 529 | Berlevåg
# Processing Weather Data for Record 530 | Indiana
# Processing Weather Data for Record 531 | Plettenberg Bay
# Error finding City
# Processing Weather Data for Record 532 | San Quintín
# Error finding City
# Processing Weather Data for Record 533 | Bulgan
# Processing Weather Data for Record 534 | Belyy Yar
# Processing Weather Data for Record 535 | Port Lincoln
# Processing Weather Data for Record 536 | Mago
# Processing Weather Data for Record 537 | Wangkui
# Error finding City
# Processing Weather Data for Record 538 | Montemurlo
# Processing Weather Data for Record 539 | Ghanzi
# Processing Weather Data for Record 540 | Morón
# Processing Weather Data for Record 541 | Birao
# Error finding City
# Processing Weather Data for Record 542 | Guangyuan
# Processing Weather Data for Record 543 | Road Town
# Processing Weather Data for Record 544 | Paamiut
# Processing Weather Data for Record 545 | Buchanan
# Processing Weather Data for Record 546 | Le Vauclin
# Processing Weather Data for Record 547 | Sakhnovshchyna
# Processing Weather Data for Record 548 | Tuatapere
# Processing Weather Data for Record 549 | Bama
# Processing Weather Data for Record 550 | Kruisfontein
# Processing Weather Data for Record 551 | Mattru
# Error finding City
# Processing Weather Data for Record 552 | Maumere
# Processing Weather Data for Record 553 | Nyagan
# Processing Weather Data for Record 554 | Joshīmath
# Error finding City
# Processing Weather Data for Record 555 | Beitbridge
# Processing Weather Data for Record 556 | Kaoma
# Processing Weather Data for Record 557 | Solnechnyy
# Processing Weather Data for Record 558 | Salina Cruz
# Processing Weather Data for Record 559 | Boyuibe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = {
    "City": City,
    "Latitude": Latitude,
    "Longitude": Longitude,
    "MaxTemp": MaxTemp,
    "Cloudiness": Cloudiness, 
    "Humidity": Humidity,
    "WindSpeed": WindSpeed,
    "Date": Date, 
}
weather_data_df = pd.DataFrame(weather_data)
weather_data_df
# Out:
#                 City  Latitude  Longitude  MaxTemp  Cloudiness  Humidity  \
# 0     Port Elizabeth  -33.9180    25.5701   295.15          75        64
# 1              Adrar   20.5022   -10.0711   293.87           0        13
# 2            Fairlie   55.7560    -4.8556   278.15          50        87
# 3        Yellowknife   62.4560  -114.3525   255.37          90        60
# 4    Arraial do Cabo  -22.9661   -42.0278   300.15           0        89
# ..               ...       ...        ...      ...         ...       ...
# 554       Beitbridge  -22.2167    30.0000   296.00           9        71
# 555            Kaoma  -14.7833    24.8000   290.46          34        96
# 556       Solnechnyy   50.7214   136.6319   268.86          77        91
# 557      Salina Cruz   16.1667   -95.2000   306.96           0        47
# 558          Boyuibe  -20.4167   -63.2833   305.15          20        40
#
#      WindSpeed Date
# 0         4.12   ZA
# 1         4.00   MR
# 2         3.13   GB
# 3         3.09   CA
# 4         3.09   BR
# ..         ...  ...
# 554       4.35   ZW
# 555       1.30   ZM
# 556       3.06   RU
# 557       4.39   MX
# 558       1.53   BO
#
# [559 rows x 8 columns]

# %%
weather_data_df.to_csv('weatherdata.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

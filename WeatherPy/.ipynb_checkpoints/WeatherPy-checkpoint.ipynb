# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?&APPID=" + weather_api_key

City = []
Latitude = []
Longitude = []
MaxTemp = []
Humidity = []
Cloudiness = []
WindSpeed = []
Date = []

print("Beginning Data Retrieval     ")
print("------------------------")

count = 1

for city in cities: 
    
    try:
        response = requests.get(f"{url}&q={city}").json()
        City.append(response["name"])
        Latitude.append(response["coord"]["lat"])
        Longitude.append(response["coord"]["lon"])
        MaxTemp.append(response["main"]["temp_max"])
        Humidity.append(response["main"]["humidity"])
        Cloudiness.append(response["clouds"]["all"])
        WindSpeed.append(response["wind"]["speed"])
        Date.append(response["sys"]["country"])
        city_name = (response["name"])
        
        print(f"Processing Weather Data for Record {count} | {city_name}")
        
        count = count + 1
        
    except:    
        print("Error finding City")
    continue
    
    print("------------------------")
    print("Data Retrieval Complete")
    print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Weather Data for Record 1 | Port Elizabeth
# Processing Weather Data for Record 2 | Adrar
# Processing Weather Data for Record 3 | Fairlie
# Processing Weather Data for Record 4 | Yellowknife
# Processing Weather Data for Record 5 | Arraial do Cabo
# Processing Weather Data for Record 6 | Cherskiy
# Error finding City
# Processing Weather Data for Record 7 | Saskylakh
# Error finding City
# Processing Weather Data for Record 8 | Valparai
# Processing Weather Data for Record 9 | Vaini
# Processing Weather Data for Record 10 | Sudak
# Processing Weather Data for Record 11 | Boende
# Processing Weather Data for Record 12 | Faanui
# Processing Weather Data for Record 13 | Ushuaia
# Processing Weather Data for Record 14 | Zhangaözen
# Processing Weather Data for Record 15 | Ryōtsu-minato
# Processing Weather Data for Record 16 | Souillac
# Processing Weather Data for Record 17 | Bandarbeyla
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = {
    "City": City,
    "Latitude": Latitude,
    "Longitude": Longitude,
    "MaxTemp": MaxTemp,
    "Cloudiness": Cloudiness, 
    "Humidity": Humidity,
    "WindSpeed": WindSpeed,
    "Date": Date, 
}
weather_data_df = pd.DataFrame(weather_data)
weather_data_df
# Out:
#                 City  Latitude  Longitude  MaxTemp  Cloudiness  Humidity  \
# 0     Port Elizabeth  -33.9180    25.5701   295.15          75        64
# 1              Adrar   20.5022   -10.0711   293.87           0        13
# 2            Fairlie   55.7560    -4.8556   278.15          50        87
# 3        Yellowknife   62.4560  -114.3525   255.37          90        60
# 4    Arraial do Cabo  -22.9661   -42.0278   300.15           0        89
# ..               ...       ...        ...      ...         ...       ...
# 554       Beitbridge  -22.2167    30.0000   296.00           9        71
# 555            Kaoma  -14.7833    24.8000   290.46          34        96
# 556       Solnechnyy   50.7214   136.6319   268.86          77        91
# 557      Salina Cruz   16.1667   -95.2000   306.96           0        47
# 558          Boyuibe  -20.4167   -63.2833   305.15          20        40
#
#      WindSpeed Date
# 0         4.12   ZA
# 1         4.00   MR
# 2         3.13   GB
# ...

# %%
weather_data_df.to_csv('weatherdata.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Check to see if any cities have humidity over 100
humidity_df = weather_data_df.loc[weather_data_df['Humidity'] >= 101]
humidity_df
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, MaxTemp, Cloudiness, Humidity, WindSpeed, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data["MaxTemp"], marker="o", color="yellow", edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Latitude vs Temperature")
plt.grid(True)
plt.savefig('latvstemp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data["Humidity"], marker="o", color="green", edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude vs Humidity")
plt.grid(True)
plt.savefig('latvshumidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data["Cloudiness"], marker="o", color="red", edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude vs Cloudiness")
plt.grid(True)
plt.savefig('latvscloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data["WindSpeed"], marker="o", color="red", edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs Wind Speed")
plt.grid(True)
plt.savefig('latvswindspeed.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hem_df = weather_data_df.loc[weather_data_df['Latitude'] >= 0]
plt.xlabel("Temperature")
plt.ylabel("Latitude")
plt.title("Max Temperature vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(northern_hem_df["MaxTemp"]).astype(float)
y_values = pd.to_numeric(northern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('northernhem_tempvslat.png')
# Out:
# y = -1.09x + 346.39

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hem_df = weather_data_df.loc[weather_data_df['Latitude'] < 0]
plt.xlabel("Temperature")
plt.ylabel("Latitude")
plt.title("Max Temperature vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(southern_hem_df["MaxTemp"]).astype(float)
y_values = pd.to_numeric(southern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('southernhem_tempvslat.png')
# Out:
# y = 1.34x + -416.62

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Humidity vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(northern_hem_df["Humidity"]).astype(float)
y_values = pd.to_numeric(northern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('northernhem_humvslat.png')
# Out:
# y = 0.22x + 23.85

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Humidity vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(southern_hem_df["Humidity"]).astype(float)
y_values = pd.to_numeric(southern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('southernhem_humvslat.png')
# Out:
# y = 0.36x + -47.23

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Cloudiness vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(northern_hem_df["Cloudiness"]).astype(float)
y_values = pd.to_numeric(northern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('northernhem_cloudvslat.png')
# Out:
# y = 0.12x + 33.04

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.ylabel("Latitude")
plt.title("Cloudiness vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(southern_hem_df["Cloudiness"]).astype(float)
y_values = pd.to_numeric(southern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('southernhem_cloudvslat.png')
# Out:
# y = 0.15x + -27.1

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Wind Speed vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(northern_hem_df["WindSpeed"]).astype(float)
y_values = pd.to_numeric(northern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('northernhem_windvslat.png')
# Out:
# y = 1.22x + 34.35

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Wind Speed vs Latitude")
plt.grid(True)
x_values = pd.to_numeric(southern_hem_df["WindSpeed"]).astype(float)
y_values = pd.to_numeric(southern_hem_df["Latitude"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
print(line_eq)
plt.savefig('southernhem_windvslat.png')
# Out:
# y = -2.16x + -13.3
